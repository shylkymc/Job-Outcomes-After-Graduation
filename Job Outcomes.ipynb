# %% [markdown]
# # THE JOB OUTCOMES AFTER GRADUATION

# %% [markdown]
# In this project, my aim is to understand the job outcomes. The data set has information about major diversity, gender diversity, median earnings, and employment rates etc. I use this data to see different role of variables by using plots. The data set is between 2010 and 2012 years. The data set was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/). And, [FiveThirtyEight](https://github.com/fivethirtyeight/data/tree/master/college-majors) cleaned and released it. So, I do not need to seperate my time to cleaning the data set. I will only analyze it.

# %% [markdown]
# ### Exploring Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
recent_grads=pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %% [markdown]
# There are null values which effect the analysis. I need to drop null values, first.

# %%
recent_grads= recent_grads.dropna()

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %% [markdown]
# ### Exploring with Scatter Plots

# %% [markdown]
# I will visualize the "Sample_size" and "Median" columns.

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title= "Median vs. Sample_size")

# %% [markdown]
# Let's take a look to the employment situation.

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(5,10))

# %%
recent_grads.plot(x="Unemployment_rate", y="Sample_size",  kind="scatter", title= 'Unemployed vs. Sample_size', figsize=(10,5))

# %% [markdown]
# I will check the full time and part time employments situation.

# %%
recent_grads.plot( x="Median",y="Full_time", kind="scatter")

# %%
recent_grads.plot( x="Median",y="Part_time", kind="scatter")

# %% [markdown]
# I will check the women's and men's situation.

# %%
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter")

# %%
recent_grads.plot(x="Median",y="Men", kind="scatter", title="Employed Men ")

# %%
recent_grads.plot( x="Median", y="Women", kind="scatter", title= "Employed Women")

# %% [markdown]
# ### Exploring with Histogram

# %% [markdown]
# Now, I will use histograms to visualization.

# %%
recent_grads['Men'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Sample_size'].hist(bins=50, range=(0,5000))

# %%
recent_grads['Sample_size'].hist(bins=10, range=(0,5000))

# %%
recent_grads['Median'].hist()

# %%
recent_grads['Employed'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Part_time'].hist(bins=25, range=(0,5000))

# %%
recent_grads['ShareWomen'].hist()

# %%
recent_grads['Unemployment_rate'].hist()

# %% [markdown]
# We can see easly these plots below.

# %%
columns= ['Sample_size', 'Median','Employed', 'Full_time', 'ShareWomen', 'Unemployment_Rate', 'Men','Women']
fig= plt.figure(figsize=(5,12))
for r in range(1,5):
    ax= fig.add_subplot(2,2,r)
    ax= recent_grads[columns[r]].plot(kind='hist', rot=40)

# %% [markdown]
# ### Exploring by Scatter Plot

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size","Median"]], figsize=(10,10) )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002F1D151C048>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]], figsize=(10,10) )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002F1D15A1F28>,
# ...
#       dtype=object)

# %% [markdown]
# ### Exploring by Bar Plots

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate')
